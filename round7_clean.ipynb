# %% [markdown]
# ## AfroBarometer
#
# Copyright 2020 Allen B. Downey
#
# [MIT License](https://opensource.org/licenses/MIT)
#
# Data from [AfroBarometer](https://www.afrobarometer.org/)
#
# Please review [the data use policies](https://www.afrobarometer.org/data/data-use-policy)
#
# It looks like the codebook for the Round 7 data is not available.
#
# [Here's the codebook for Round 6](https://afrobarometer.org/data/merged-round-6-codebook-36-countries-2016)
#
# [Some of the questionnaires are here](https://afrobarometer.org/surveys-and-methods/questionnaires)
#
# [Here is the download page for the Merged Data](https://www.afrobarometer.org/data/merged-data)

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    # !pip install pyreadstat

# %%
import os

filename = 'r7_merged_data_34ctry.release.sav'
if not os.path.exists(filename):
    # !wget https://afrobarometer.org/sites/default/files/data/round-7/r7_merged_data_34ctry.release.sav

# %%
import pandas as pd

# %time df = pd.read_spss('r7_merged_data_34ctry.release.sav')
# Out:
# CPU times: user 18.3 s, sys: 1.35 s, total: 19.7 s
# Wall time: 19.7 s

# %%
df.shape
# Out:
# (45823, 366)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#     RESPNO COUNTRY COUNTRY_Old.order COUNTRY_R5List COUNTRY_R6List  \
# 0  BEN0001   Benin             Benin          Benin          Benin
# 1  BEN0002   Benin             Benin          Benin          Benin
# 2  BEN0003   Benin             Benin          Benin          Benin
# 3  BEN0004   Benin             Benin          Benin          Benin
# 4  BEN0005   Benin             Benin          Benin          Benin
#
#   COUNTRY.BY.REGION URBRUR      REGION LOCATION.LEVEL.1 EA_SVC_A EA_SVC_B  \
# 0       West Africa  Rural        Mono          LOKOSSA      Yes      Yes
# 1       West Africa  Rural        Mono          LOKOSSA      Yes      Yes
# 2       West Africa  Urban  Atlantique    ABOMEY-CALAVI      Yes      Yes
# 3       West Africa  Urban  Atlantique    ABOMEY-CALAVI      Yes      Yes
# 4       West Africa  Urban  Atlantique    ABOMEY-CALAVI      Yes      Yes
#
#   EA_SVC_C EA_SVC_D EA_FAC_A EA_FAC_B EA_FAC_C EA_FAC_D EA_FAC_E EA_FAC_F  \
# 0       No      Yes       No      Yes       No      Yes      Yes       No
# 1       No      Yes       No      Yes       No      Yes      Yes       No
# 2       No      Yes      Yes      Yes      Yes      Yes      Yes      Yes
# 3       No      Yes      Yes      Yes      Yes      Yes      Yes      Yes
# 4       No      Yes      Yes      Yes      Yes      Yes      Yes      Yes
#
#   EA_FAC_G EA_SEC_A EA_SEC_B EA_SEC_C EA_SEC_D EA_SEC_E      EA_ROAD_A  \
# 0      Yes       No      Yes       No       No       No          Earth
# 1      Yes       No      Yes       No       No       No          Earth
# 2      Yes      Yes       No       No       No       No  Paved/ Tarred
# 3      Yes      Yes       No       No       No       No  Paved/ Tarred
# 4      Yes      Yes       No       No       No       No  Paved/ Tarred
#
#   EA_ROAD_B EA_ROAD_C                  NOCALL_1 NOCALL_1OTHER  \
# 0     Earth      Poor  Interview was successful
# 1     Earth      Poor  Interview was successful
# 2     Earth      Poor  Interview was successful
# 3     Earth      Poor  Interview was successful
# 4     Earth      Poor  Interview was successful
#
#                    NOCALL_2 NOCALL_2OTHER                  NOCALL_3  \
# 0  Interview was successful                Interview was successful
# 1  Interview was successful                Interview was successful
# 2  Interview was successful                Interview was successful
# 3  Interview was successful                Interview was successful
# 4  Interview was successful                Interview was successful
#
#   NOCALL_3OTHER                  NOCALL_4 NOCALL_4OTHER  \
# 0                Interview was successful
# 1                Interview was successful
# 2                Interview was successful
# 3                Interview was successful
# 4                Interview was successful
#
#                    NOCALL_5                  NOCALL_6  \
# 0  Interview was successful  Interview was successful
# 1  Interview was successful  Interview was successful
# 2  Interview was successful  Interview was successful
# 3  Interview was successful  Interview was successful
# 4  Interview was successful  Interview was successful
#
#                    NOCALL_7 NOCALL_7OTHER                  NOCALL_8 THISINT  \
# 0  Interview was successful                Interview was successful  Female
# 1  Interview was successful                Interview was successful  Female
# 2  Interview was successful                Interview was successful  Female
# 3  Interview was successful                Interview was successful    Male
# 4  Interview was successful                Interview was successful    Male
#
#    ADULT_CT  CALLS    DATEINTR   STRTIME  Q1          Q2A     Q2AOTHER  \
# 0       2.0    1.0  2016-12-25  12:53:17  21      Adjagbé
# 1       1.0    1.0  2016-12-25  13:28:36  45      Adjagbé
# 2       3.0    1.0  2016-12-24  15:02:29  22       Fongbé
# 3       1.0    1.0  2016-12-24  15:12:51  30  Gourmantché  GOURMANTCHÉ
# 4      16.0    1.0  2016-12-24  15:09:56  28       Yoruba
#
#        Q2B Q2BOTHER                            Q3          Q4A  \
# 0  Adjagbé           Going in the right direction   Fairly Bad
# 1  Adjagbé           Going in the wrong direction  Fairly Good
# 2   Fongbé           Going in the right direction  Fairly Good
# 3   Fongbé           Going in the right direction     Very Bad
# 4   Yoruba           Going in the wrong direction     Very Bad
#
#                     Q4B      Q5          Q6          Q7            Q8A  \
# 0           Fairly Good   Worse  Much worse  Much worse  Several times
# 1           Fairly Good    Same       Worse      Better          Never
# 2  Neither good nor bad  Better  Much worse       Worse     Many times
# 3            Fairly Bad    Same       Worse      Better          Never
# 4           Fairly Good  Better  Much worse       Worse  Several times
#
#           Q8B                 Q8C            Q8D                 Q8E  \
# 0  Many times       Several times          Never          Many times
# 1       Never               Never          Never  Just once or twice
# 2       Never               Never          Never          Many times
# 3       Never               Never          Never  Just once or twice
# 4       Never  Just once or twice  Several times          Many times
#
#                           Q8F                                         Q9  \
# 0        Several times a week                                   Somewhat
# 1              Not applicable  Not at all / Does not receive remittances
# 2  Two or three times a month  Not at all / Does not receive remittances
# 3              Not applicable  Not at all / Does not receive remittances
# 4        Several times a week  Not at all / Does not receive remittances
#
#             Q10A   Q10B Q11A Q11B                    Q12A  \
# 0  Several times  Never   No   No  Less than once a month
# 1          Never  Never   No   No                   Never
# 2          Never  Never   No   No      A few times a week
# 3  Several times  Never   No   No               Every day
# 4          Never  Never   No   No      A few times a week
#
#                   Q12B                    Q12C                 Q12D  \
# 0                Never                   Never                Never
# 1                Never                   Never                Never
# 2  A few times a month               Every day            Every day
# 3            Every day  Less than once a month            Every day
# 4   A few times a week      A few times a week  A few times a month
#
#                   Q12E           Q13              Q14  \
# 0                Never  Occasionally    Somewhat free
# 1                Never    Frequently  Completely free
# 2            Every day  Occasionally    Somewhat free
# 3            Every day  Occasionally    Not very free
# 4  A few times a month  Occasionally    Somewhat free
#
#                           Q15                         Q16  \
# 0                Agree with 2  Agree very strongly with 2
# 1  Agree very strongly with 2  Agree very strongly with 2
# 2                Agree with 2                Agree with 2
# 3          Agree with neither                Agree with 2
# 4  Agree very strongly with 2  Agree very strongly with 2
#
#                           Q17               Q18A               Q18B  \
# 0  Agree very strongly with 2    Not very likely    Somewhat likely
# 1  Agree very strongly with 1  Not at all likely        Very likely
# 2                Agree with 2  Not at all likely        Very likely
# 3                Agree with 2  Not at all likely  Not at all likely
# 4                Agree with 2  Not at all likely  Not at all likely
#
#               Q18C               Q18D                   Q19A  \
# 0  Not very likely        Very likely  Somewhat less freedom
# 1  Somewhat likely        Very likely      Much more freedom
# 2  Somewhat likely  Not at all likely  Somewhat less freedom
# 3  Somewhat likely    Somewhat likely                   Same
# 4  Not very likely    Somewhat likely                   Same
#
#                     Q19B                   Q19C                   Q19D  \
# 0  Somewhat less freedom  Somewhat less freedom  Somewhat less freedom
# 1      Much more freedom  Somewhat more freedom      Much more freedom
# 2  Somewhat less freedom      Much less freedom      Much less freedom
# 3      Much more freedom      Much less freedom                   Same
# 4                   Same      Much less freedom      Much less freedom
#
#                     Q19E             Q20A           Q20B  \
# 0  Somewhat less freedom     Not a Member  Active Member
# 1  Somewhat more freedom  Official Leader  Active Member
# 2      Much less freedom    Active Member  Active Member
# 3                   Same     Not a Member   Not a Member
# 4  Somewhat less freedom     Not a Member   Not a Member
#
#                                  Q21A                                Q21B  \
# 0                  Yes, several times                  Yes, several times
# 1                          Yes, often  No, but would do if had the chance
# 2                  Yes, several times                  Yes, several times
# 3  No, but would do if had the chance  No, but would do if had the chance
# 4  No, but would do if had the chance                  Yes, once or twice
#
#                                Q22                                     Q23  \
# 0       You voted in the elections                Completely free and fair
# 1       You voted in the elections                Completely free and fair
# 2  You were not registered to vote                       Not free and fair
# 3       You voted in the elections  Free and fair, but with minor problems
# 4       You voted in the elections                Completely free and fair
#
#   Q24A Q24B         Q25A   Q25B   Q25C         Q25D   Q25E         Q25F  \
# 0  Yes  Yes        Never  Never  Never    Only once  Never  A few times
# 1  Yes  Yes  A few times  Never  Never  A few times  Never  A few times
# 2   No   No        Never  Never  Never        Never  Never        Never
# 3   No   No        Never  Never  Never        Never  Never        Never
# 4  Yes   No        Never  Never  Never        Never  Never    Only once
#
#                                  Q26A                                Q26B  \
# 0  No, but would do if had the chance  No, but would do if had the chance
# 1  No, but would do if had the chance  No, but would do if had the chance
# 2             No, would never do this             No, would never do this
# 3             No, would never do this             No, would never do this
# 4  No, but would do if had the chance  No, but would do if had the chance
#
#                                  Q26C                     Q26D  \
# 0  No, but would do if had the chance       Yes, several times
# 1  No, but would do if had the chance  No, would never do this
# 2             No, would never do this  No, would never do this
# 3             No, would never do this  No, would never do this
# 4  No, but would do if had the chance  No, would never do this
#
#                                  Q26E                 Q27A  \
# 0  No, but would do if had the chance  Strongly Disapprove
# 1  No, but would do if had the chance  Strongly Disapprove
# 2             No, would never do this  Strongly Disapprove
# 3             No, would never do this  Strongly Disapprove
# 4  No, but would do if had the chance  Strongly Disapprove
#
#                   Q27B                 Q27C  \
# 0     Strongly Approve  Strongly Disapprove
# 1  Strongly Disapprove  Strongly Disapprove
# 2  Strongly Disapprove  Strongly Disapprove
# 3  Strongly Disapprove  Strongly Disapprove
# 4     Strongly Approve  Strongly Disapprove
#
#                                                 Q28  \
# 0                       STATEMENT 3: Doesn't matter
# 1                 STATEMENT 1: Democracy preferable
# 2                 STATEMENT 1: Democracy preferable
# 3                 STATEMENT 1: Democracy preferable
# 4  STATEMENT 2: Sometimes non-democratic preferable
#
#                           Q29                         Q30  \
# 0                Agree with 2  Agree very strongly with 1
# 1  Agree very strongly with 2  Agree very strongly with 1
# 2  Agree very strongly with 1  Agree very strongly with 1
# 3                Agree with 2  Agree very strongly with 1
# 4                Agree with 2  Agree very strongly with 1
#
#                           Q31                         Q32  \
# 0  Agree very strongly with 2  Agree very strongly with 1
# 1                Agree with 2  Agree very strongly with 1
# 2                Agree with 2  Agree very strongly with 1
# 3                Agree with 2  Agree very strongly with 1
# 4                Agree with 1  Agree very strongly with 1
#
#                           Q33                         Q34  \
# 0  Agree very strongly with 2                Agree with 1
# 1  Agree very strongly with 2  Agree very strongly with 1
# 2  Agree very strongly with 1                Agree with 1
# 3                Agree with 2                Agree with 1
# 4  Agree very strongly with 2  Agree very strongly with 1
#
#                                     Q35                   Q36  \
# 0                      A full democracy    Not very satisfied
# 1  A democracy, but with minor problems      Fairly satisfied
# 2      A democracy, with major problems    Not very satisfied
# 3  A democracy, but with minor problems      Fairly satisfied
# 4  A democracy, but with minor problems  Not at all satisfied
#
#                           Q37            Q38A            Q38B            Q38C  \
# 0  Agree very strongly with 1        Disagree        Disagree           Agree
# 1                Agree with 1  Strongly Agree  Strongly Agree           Agree
# 2                Agree with 1        Disagree           Agree           Agree
# 3  Agree very strongly with 1  Strongly Agree  Strongly Agree           Agree
# 4  Agree very strongly with 1  Strongly Agree  Strongly Agree  Strongly Agree
#
#                 Q38D               Q38E      Q38F      Q38G    Q39A   Q39B  \
# 0  Strongly Disagree           Disagree  Disagree     Agree  Always  Never
# 1  Strongly Disagree     Strongly Agree  Disagree     Agree  Rarely  Never
# 2           Disagree              Agree     Agree     Agree   Often  Often
# 3  Strongly Disagree  Strongly Disagree  Disagree     Agree  Rarely  Never
# 4     Strongly Agree              Agree  Disagree  Disagree   Often  Often
#
#      Q39C           Q40        Q41    Q42A    Q42B    Q42C   Q42D   Q42E  \
# 0   Never  A little bit      Never   Often   Never  Always  Often  Never
# 1   Never    Not at all      Never   Never   Never   Never  Never  Never
# 2   Never  A little bit  Sometimes   Often   Often   Often  Never  Never
# 3  Rarely    Not at all  Sometimes  Always  Rarely   Often  Never  Often
# 4   Often         A lot      Never   Often   Often   Never  Often  Often
#
#     Q42F           Q43A           Q43B           Q43C           Q43D  \
# 0  Often          A lot       Somewhat       Somewhat          A lot
# 1  Never       Somewhat       Somewhat       Somewhat       Somewhat
# 2  Never  Just a little  Just a little  Just a little  Just a little
# 3  Never       Somewhat       Somewhat       Somewhat       Somewhat
# 4  Never     Not at all     Not at all       Somewhat       Somewhat
#
#             Q43E                             Q43F           Q43G  \
# 0          A lot                         Somewhat          A lot
# 1       Somewhat  Don’t know/Haven’t heard enough       Somewhat
# 2  Just a little                    Just a little  Just a little
# 3       Somewhat                         Somewhat          A lot
# 4     Not at all                    Just a little  Just a little
#
#             Q43H           Q43I                             Q43J  \
# 0          A lot          A lot                            A lot
# 1       Somewhat       Somewhat  Don’t know/Haven’t heard enough
# 2  Just a little  Just a little                       Not at all
# 3          A lot          A lot                            A lot
# 4  Just a little     Not at all                         Somewhat
#
#             Q43K          Q44A          Q44B          Q44C          Q44D  \
# 0          A lot  Some of them  Most of them  Most of them  Some of them
# 1       Somewhat          None          None  Some of them  Some of them
# 2  Just a little  Most of them  Most of them  Most of them  Most of them
# 3          A lot  Some of them  Some of them  Some of them  Some of them
# 4          A lot  Most of them  Most of them  Some of them  Most of them
#
#            Q44E          Q44F                       Q44G  \
# 0  Some of them  Some of them               Some of them
# 1  Some of them  Most of them  Don't know/ Haven’t heard
# 2  Most of them  Most of them               Most of them
# 3  Some of them  Some of them               Some of them
# 4  Most of them  Most of them               Some of them
#
#                         Q44H          Q44I          Q44J                 Q45  \
# 0               Some of them  Some of them  Most of them     Decreased a lot
# 1               Some of them  Most of them  Some of them  Decreased somewhat
# 2  Don't know/ Haven’t heard  Most of them  Most of them  Decreased somewhat
# 3               Some of them  Some of them  Some of them     Stayed the same
# 4                       None   All of them  Some of them     Stayed the same
#
#                  Q46                      Q47             Q48A  \
# 0  Strongly Disagree         Risk retaliation  Not very likely
# 1              Agree  Can report without fear  Not very likely
# 2              Agree               Don’t know  Not very likely
# 3              Agree  Can report without fear  Somewhat likely
# 4              Agree         Risk retaliation  Somewhat likely
#
#                 Q48B               Q48C               Q48D               Q48E  \
# 0        Very likely  Not at all likely    Not very likely    Not very likely
# 1    Somewhat likely    Not very likely    Not very likely    Somewhat likely
# 2  Not at all likely  Not at all likely  Not at all likely  Not at all likely
# 3    Somewhat likely    Somewhat likely    Somewhat likely    Somewhat likely
# 4  Not at all likely  Not at all likely        Very likely        Very likely
#
#               Q48F Q49A        Q49B        Q49C Q49D        Q49E  \
# 0  Not very likely   No  No contact  No contact   No  No contact
# 1  Not very likely   No  No contact  No contact   No  No contact
# 2      Very likely   No  No contact  No contact  Yes        Easy
# 3  Somewhat likely   No  No contact  No contact  Yes        Easy
# 4  Somewhat likely   No  No contact  No contact   No  No contact
#
#                  Q49F        Q49G Q49H        Q49I                Q49J  \
# 0          No contact  No contact  Yes        Easy  After a short time
# 1          No contact  No contact   No  No contact          No contact
# 2          Right away       Never   No  No contact          No contact
# 3  After a short time       Never  Yes        Easy  After a short time
# 4          No contact  No contact   No  No contact          No contact
#
#           Q49K Q49L        Q49M        Q49N Q49O        Q49P        Q49Q  \
# 0        Never   No  No contact  No contact   No  No contact  No contact
# 1   No contact   No  No contact  No contact   No  No contact  No contact
# 2   No contact   No  No contact  No contact  Yes        Easy  Right away
# 3  A few times   No  No contact  No contact   No  No contact  No contact
# 4   No contact   No  No contact  No contact   No  No contact  No contact
#
#          Q49R   Q49S        Q49T           Q50          Q51        Q52  \
# 0  No contact  Never  No contact      Somewhat  Much better     Always
# 1  No contact  Never  No contact      Somewhat        Worse      Never
# 2       Never  Never  No contact    Not at all       Better  Sometimes
# 3  No contact  Never  No contact  A little bit         Same     Always
# 4  No contact  Never  No contact      Somewhat        Worse  Sometimes
#
#                 Q53A             Q53B             Q53C            Q54A  \
# 0        Very likely  Somewhat likely      Very likely           Never
# 1        Very likely      Very likely      Very likely           Never
# 2  Not at all likely  Somewhat likely  Somewhat likely  Only Sometimes
# 3    Somewhat likely  Somewhat likely  Somewhat likely  Only Sometimes
# 4    Somewhat likely  Not very likely  Somewhat likely  Only Sometimes
#
#              Q54B                     Q55PT1 Q55PT1OTHER  \
# 0          Always               Unemployment
# 1           Often               Unemployment
# 2           Often  Management of the economy
# 3  Only Sometimes               Unemployment
# 4           Often        Poverty/destitution
#
#                        Q55PT2                           Q55PT2OTHER  \
# 0         Poverty/destitution
# 1                       Other  IMPORTATION VERS L'EXTÉRIEUR DU PAYS
# 2                   Education
# 3  Discrimination/ inequality
# 4                Unemployment
#
#                 Q55PT3 Q55PT3OTHER                               Q56A  \
# 0       Loans / credit                                    Fairly Well
# 1               Health              Don't know / Haven’t heard enough
# 2          Electricity                                     Very Badly
# 3  Poverty/destitution                                     Very Badly
# 4            Education                                     Very Badly
#
#            Q56B          Q56C         Q56D          Q56E          Q56F  \
# 0   Fairly Well   Fairly Well  Fairly Well   Fairly Well     Very Well
# 1    Very Badly    Very Badly  Fairly Well  Fairly Badly  Fairly Badly
# 2    Very Badly    Very Badly   Very Badly    Very Badly    Very Badly
# 3  Fairly Badly  Fairly Badly    Very Well    Very Badly   Fairly Well
# 4    Very Badly    Very Badly   Very Badly  Fairly Badly  Fairly Badly
#
#            Q56G         Q56H                               Q56I         Q56J  \
# 0     Very Well    Very Well                          Very Well  Fairly Well
# 1    Very Badly    Very Well                        Fairly Well  Fairly Well
# 2  Fairly Badly  Fairly Well                         Very Badly   Very Badly
# 3   Fairly Well  Fairly Well  Don't know / Haven’t heard enough   Very Badly
# 4    Very Badly  Fairly Well                        Fairly Well   Very Badly
#
#            Q56K          Q56L         Q56M         Q56N          Q56O  \
# 0     Very Well     Very Well    Very Well    Very Well   Fairly Well
# 1   Fairly Well    Very Badly   Very Badly  Fairly Well   Fairly Well
# 2    Very Badly    Very Badly   Very Badly   Very Badly    Very Badly
# 3    Very Badly    Very Badly  Fairly Well  Fairly Well     Very Well
# 4  Fairly Badly  Fairly Badly  Fairly Well  Fairly Well  Fairly Badly
#
#                        Q56P                               Q56Q        Q56R  \
# 0  Not asked in the country                          Very Well   Very Well
# 1  Not asked in the country  Don't know / Haven’t heard enough  Very Badly
# 2  Not asked in the country                        Fairly Well  Very Badly
# 3  Not asked in the country                       Fairly Badly  Very Badly
# 4  Not asked in the country                       Fairly Badly  Very Badly
#
#                                 Q56S    Q57A        Q57B         Q57C  \
# 0                          Very Well   Worse      Better         Same
# 1  Don't know / Haven’t heard enough   Worse        Same  Much better
# 2                         Very Badly    Same        Same         Same
# 3                        Fairly Well  Better      Better       Better
# 4                       Fairly Badly    Same  Much worse  Much better
#
#           Q57D        Q57E         Q57F        Q57G                 Q58A  \
# 0  Much better      Better  Much better      Better  Strongly Disapprove
# 1       Better      Better         Same      Better           Disapprove
# 2         Same  Don’t know   Don’t know        Same           Disapprove
# 3       Better        Same         Same        Same           Disapprove
# 4         Same  Much worse   Much worse  Much worse  Strongly Disapprove
#
#          Q58B                               Q58C            Q58D  \
# 0     Approve                            Approve         Approve
# 1     Approve                            Approve  Not applicable
# 2  Disapprove  Don’t know / haven't heard enough      Disapprove
# 3     Approve                            Approve         Approve
# 4  Disapprove                         Disapprove         Approve
#
#                                 Q58E                              Q59A  \
# 0                            Approve                        The Voters
# 1                            Approve  The Parliament / County Assembly
# 2  Don’t know / haven't heard enough  The Parliament / County Assembly
# 3                            Approve  The Parliament / County Assembly
# 4                         Disapprove                        The Voters
#
#          Q59B                              Q59C  \
# 0  The Voters                        The Voters
# 1  The Voters  The Parliament / County Assembly
# 2  Don’t know                        The Voters
# 3  The Voters  The Parliament / County Assembly
# 4  The Voters  The Parliament / County Assembly
#
#                                 Q60A                               Q60B  \
# 0  Yes, feared but didn't experience        Yes, feared and experienced
# 1                          No, never                          No, never
# 2                          No, never                          No, never
# 3                          No, never                          No, never
# 4                          No, never  Yes, feared but didn't experience
#
#                                 Q60C                      Q60D       Q61A  \
# 0        Yes, feared and experienced  Not asked in the country     Always
# 1                          No, never  Not asked in the country      Often
# 2  Yes, feared but didn't experience  Not asked in the country  Sometimes
# 3                          No, never  Not asked in the country     Rarely
# 4                          No, never  Not asked in the country      Often
#
#         Q61B       Q61C                         Q62  \
# 0      Often      Often                Agree with 1
# 1      Often      Often                Agree with 1
# 2  Sometimes  Sometimes  Agree very strongly with 1
# 3     Rarely     Rarely                Agree with 1
# 4      Often     Rarely  Agree very strongly with 1
#
#                           Q63                         Q64  \
# 0                Agree with 2                Agree with 2
# 1  Agree very strongly with 2  Agree very strongly with 1
# 2  Agree very strongly with 1                  Don't know
# 3                Agree with 1                Agree with 2
# 4  Agree very strongly with 2                Agree with 2
#
#                           Q65             Q66 Q67          Q68A  \
# 0  Agree very strongly with 2  Very difficult  No      Somewhat
# 1  Agree very strongly with 1  Very difficult  No  A little bit
# 2                Agree with 2  Very difficult  No    Don’t know
# 3                Agree with 2            Easy  No    Not at all
# 4                Agree with 2       Difficult  No    Not at all
#
#                                                 Q68B  \
# 0  You are planning to move in the next year or t...
# 1  You are not currently making any specific plan...
# 2                                         Don't know
# 3                                     Not applicable
# 4                                     Not applicable
#
#                                             Q69  \
# 0  Most prominent destination country in region
# 1                                        Europe
# 2                                        Europe
# 3                                Not applicable
# 4                                Not applicable
#
#                                                  Q70 Q70OTHER             Q71  \
# 0                                  Economic hardship                    Worse
# 1  Travel/tourism/adventure/experience other cult...                    Worse
# 2                                          Find work           About the same
# 3                                     Not applicable           About the same
# 4                                     Not applicable                    Worse
#
#                    Q72A                  Q72B Q73A  \
# 0  Somewhat less severe  Somewhat more severe  Yes
# 1  Somewhat more severe       Stayed the same  Yes
# 2       Stayed the same            Don’t know   No
# 3       Stayed the same       Stayed the same  Yes
# 4  Somewhat more severe  Somewhat more severe  Yes
#
#                               Q73B                                        Q74  \
# 0  Positive changes in the weather                          Natural processes
# 1  Negative changes in the weather                             Human Activity
# 2                   Not applicable                             Not applicable
# 3  Negative changes in the weather  Both human activity and natural processes
# 4  Negative changes in the weather                             Human Activity
#
#                Q75                                                Q76  \
# 0  Somewhat better      No, climate change doesn’t need to be stopped
# 1   Somewhat worse  Yes, Ordinary African citizens can do a little...
# 2   Not applicable                                     Not applicable
# 3   Somewhat worse        Yes, Ordinary African citizens can do a lot
# 4   Somewhat worse  Yes, Ordinary African citizens can do a little...
#
#              Q77A            Q77B            Q77C            Q77D  \
# 0  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 1  Strongly Agree  Strongly Agree  Strongly Agree  Strongly Agree
# 2           Agree           Agree           Agree           Agree
# 3           Agree        Disagree        Disagree        Disagree
# 4           Agree        Disagree           Agree           Agree
#
#                   Q78A                 Q78B          Q84     Q84OTHER  \
# 0     Always justified  Sometimes justified         Adja
# 1  Sometimes justified      Never justified         Adja
# 2  Sometimes justified  Sometimes justified          Fon
# 3      Never justified      Never justified  Gourmantché  GOURMANTCHÉ
# 4      Never justified  Sometimes justified       Yoruba
#
#          Q85A                                               Q85B  \
# 0   Sometimes  I feel equally (national identity) and (ethnic...
# 1       Never  I feel equally (national identity) and (ethnic...
# 2  Don’t know                                         Don't know
# 3     Missing                                            Missing
# 4   Sometimes  I feel equally (national identity) and (ethnic...
#
#             Q86A   Q86B   Q86C   Q86D            Q87A            Q87B  \
# 0  Several times  Never  Never  Never  Would not care   Somewhat like
# 1          Never  Never  Never  Never   Strongly like   Strongly like
# 2          Never  Never  Never  Never  Would not care  Would not care
# 3          Never  Never  Never  Never  Would not care  Would not care
# 4          Never  Never  Never  Never   Strongly like   Strongly like
#
#                Q87C            Q87D                         Q88A  \
# 0    Would not care   Strongly like                      Refused
# 1  Strongly dislike   Strongly like  Yes, feels close to a party
# 2    Would not care  Would not care   No, not close to any party
# 3    Would not care  Would not care   No, not close to any party
# 4  Strongly dislike   Strongly like   No, not close to any party
#
#                                          Q88B Q88BOTHER  \
# 0                              Not applicable
# 1  Force Cauris pour un Bénin Emergent (FCBE)
# 2                              Not applicable
# 3                              Not applicable
# 4                              Not applicable
#
#                      Q89A                    Q89B                    Q89C  \
# 0  Yes, someone else owns           No, don’t own           No, don’t own
# 1           No, don’t own           No, don’t own           No, don’t own
# 2  Yes, someone else owns  Yes, someone else owns  Yes, someone else owns
# 3             Yes, do own             Yes, do own             Yes, do own
# 4             Yes, do own             Yes, do own             Yes, do own
#
#             Q89D           Q89E         Q89F  \
# 0  No, don’t own  No, don’t own  Yes, do own
# 1  No, don’t own  No, don’t own  Yes, do own
# 2  No, don’t own    Yes, do own  Yes, do own
# 3    Yes, do own    Yes, do own  Yes, do own
# 4  No, don’t own  No, don’t own  Yes, do own
#
#                                  Q90      Q91A                 Q91B  \
# 0  No, does not have internet access  Everyday                Never
# 1  No, does not have internet access  Everyday                Never
# 2                  Yes, has internet  Everyday             Everyday
# 3                  Yes, has internet  Everyday             Everyday
# 4  No, does not have internet access  Everyday  A few times a month
#
#                    Q92A                  Q92B  \
# 0  Outside the compound  Outside the compound
# 1  Outside the compound            No latrine
# 2      Inside the house      Inside the house
# 3      Inside the house      Inside the house
# 4   Inside the compound   Inside the compound
#
#                                                  Q93              Q94  \
# 0                                       Occasionally   Yes, part time
# 1  No mains electric supply or connection to the ...      No, looking
# 2  No mains electric supply or connection to the ...  No, not looking
# 3                                   Most of the time   Yes, full time
# 4                                    All of the time      No, looking
#
#                                Q95A            Q95B  \
# 0             Housewife / homemaker  Not applicable
# 1  Artisan or skilled manual worker  Works for self
# 2                           Student  Not applicable
# 3           Clerical or secretarial      Government
# 4                           Student  Not applicable
#
#                                               Q95C                 Q96A  \
# 0  You make the decisions jointly with your spouse  Respondent's spouse
# 1                  You make the decisions yourself      You(respondent)
# 2                  You make the decisions yourself  Respondent's father
# 3                  You make the decisions yourself      You(respondent)
# 4  You make the decisions jointly with your spouse      You(respondent)
#
#                                          Q96B  \
# 0  Agriculture / farming / fishing / forestry
# 1                              Not applicable
# 2                    Upper-level professional
# 3                              Not applicable
# 4                              Not applicable
#
#                                    Q97             Q98 Q98OTHER  \
# 0  Some secondary school / high school     Pentecostal
# 1               Some primary schooling     Evangelical
# 2                      Some university     Muslim only
# 3                 University completed  Roman Catholic
# 4                      Some university  Roman Catholic
#
#               Q99 Q99OTHER           Q100   ENDTIME   LENGTH    Q101  \
# 0  Nouveau Départ              Government  14:23:34  90.2842  Female
# 1         Refused              Government  14:08:57  40.3399  Female
# 2  Would not vote           Afrobarometer  16:49:07  106.644  Female
# 3  Would not vote           Afrobarometer  16:41:14  88.3739    Male
# 4           Other   LIONEL  Afrobarometer  16:37:46  87.8381    Male
#
#               Q102 Q102OTHER     Q103 Q103OTHER  \
# 0  Black / African            Adjagbé
# 1  Black / African            Adjagbé
# 2  Black / African             French
# 3  Black / African             French
# 4  Black / African             French
#
#                              Q104                          Q105  \
# 0         Traditional house / hut               Thatch or grass
# 1  Non-traditional / formal house  Metal, aluminum, tin or zinc
# 2  Non-traditional / formal house                      Concrete
# 3  Non-traditional / formal house  Metal, aluminum, tin or zinc
# 4  Non-traditional / formal house                         Tiles
#
#             Q106 Q107A Q107B Q107C Q107D Q107E       Q108 Q108_2       Q110A  \
# 0   A few others    No    No    No    No    No  Not asked    All    Friendly
# 1  Children only    No    No    No    No    No  Not asked   Most    Friendly
# 2   A few others   Yes    No    No    No    No  Not asked    All  In between
# 3         No one    No    No    No    No    No  Not asked    All    Friendly
# 4         No one    No    No    No    No    No  Not asked    All    Friendly
#
#         Q110B        Q110C       Q110D       Q110E       Q110F   Q112  Q113  \
# 0  Interested   In between  In between     At ease      Honest  BEN53  24.0
# 1  Interested  Cooperative     Patient     At ease      Honest  BEN52  26.0
# 2  In between   In between  In between  In between  In between  BEN16  21.0
# 3  Interested  Cooperative     Patient     At ease      Honest  BEN15  27.0
# 4  Interested  Cooperative     Patient     At ease      Honest  BEN14  23.0
#
#      Q114   Q115     Q116 Q116OTHER     Q117 Q117OTHER                  Q118  \
# 0  Female  Urban  Adjagbé            Adjagbé                 Some university
# 1    Male  Urban  Adjagbé            Adjagbé            University completed
# 2  Female  Rural   Fongbé             Fongbé                 Some university
# 3  Female  Urban  Adjagbé            Adjagbé            University completed
# 4    Male  Urban   Fongbé             Fongbé            University completed
#
#     Q119_1            Q119_2            Q119_3            Q119_4  \
# 0  Adjagbé  No further reply  No further reply  No further reply
# 1   French           Adjagbé            Fongbé  No further reply
# 2   Fongbé  No further reply  No further reply  No further reply
# 3  Adjagbé            Fongbé  No further reply  No further reply
# 4   French            Fongbé  No further reply  No further reply
#
#              Q119_5            Q119_6            Q119_7               Q119_8  \
# 0  No further reply  No further reply  No further reply  No Further Response
# 1  No further reply  No further reply  No further reply  No Further Response
# 2  No further reply  No further reply  No further reply  No Further Response
# 3  No further reply  No further reply  No further reply  No Further Response
# 4  No further reply  No further reply  No further reply  No Further Response
#
#                 Q119_9              Q119_10              Q119_11 Q119OTHER  \
# 0  No Further Response  No Further Response  No Further Response
# 1  No Further Response  No Further Response  No Further Response
# 2  No Further Response  No Further Response  No Further Response
# 3  No Further Response  No Further Response  No Further Response
# 4  No Further Response  No Further Response  No Further Response
#
#    withinwt  Combinwt URBRUR_COND AGE_COND       EDUC_COND RELIG_COND  \
# 0  1.014967  1.014967       Rural    18-25       Secondary  Christian
# 1  1.014967  1.014967       Rural    36-45         Primary  Christian
# 2  3.376287  3.376287       Urban    18-25  Post-secondary     Muslim
# 3  3.376287  3.376287       Urban    26-35  Post-secondary  Christian
# 4  3.376287  3.376287       Urban    26-35  Post-secondary  Christian
#
#    LivedPoverty        LivedPoverty_CAT                   DemandDemo  \
# 0           2.0  Moderate Lived Poverty  Agrees w/ 2 of 4 components
# 1           0.2       Low Lived Poverty    Full demand for democracy
# 2           1.2  Moderate Lived Poverty    Full demand for democracy
# 3           0.2       Low Lived Poverty    Full demand for democracy
# 4           1.6  Moderate Lived Poverty  Agrees w/ 2 of 4 components
#
#                                           SupplyDemo       R1.only  \
# 0                  Perceives supply of one, not both  Not Selected
# 1  Perceives full supply of democracy (Extent +Sa...  Not Selected
# 2                                Perceives no supply  Not Selected
# 3  Perceives full supply of democracy (Extent +Sa...  Not Selected
# 4                  Perceives supply of one, not both  Not Selected
#
#         R2.only   R3.only   R4.only   R5.only   R6.only
# 0  Not Selected  Selected  Selected  Selected  Selected
# 1  Not Selected  Selected  Selected  Selected  Selected
# 2  Not Selected  Selected  Selected  Selected  Selected
# 3  Not Selected  Selected  Selected  Selected  Selected
# 4  Not Selected  Selected  Selected  Selected  Selected

# %%
for name in df.columns:
    print(name)
# Out:
# RESPNO
# COUNTRY
# COUNTRY_Old.order
# COUNTRY_R5List
# COUNTRY_R6List
# COUNTRY.BY.REGION
# URBRUR
# REGION
# LOCATION.LEVEL.1
# EA_SVC_A
# EA_SVC_B
# EA_SVC_C
# EA_SVC_D
# EA_FAC_A
# EA_FAC_B
# EA_FAC_C
# EA_FAC_D
# EA_FAC_E
# EA_FAC_F
# EA_FAC_G
# EA_SEC_A
# EA_SEC_B
# EA_SEC_C
# EA_SEC_D
# EA_SEC_E
# EA_ROAD_A
# EA_ROAD_B
# EA_ROAD_C
# NOCALL_1
# NOCALL_1OTHER
# NOCALL_2
# NOCALL_2OTHER
# NOCALL_3
# NOCALL_3OTHER
# NOCALL_4
# NOCALL_4OTHER
# NOCALL_5
# NOCALL_6
# NOCALL_7
# NOCALL_7OTHER
# NOCALL_8
# THISINT
# ADULT_CT
# CALLS
# DATEINTR
# STRTIME
# Q1
# Q2A
# Q2AOTHER
# Q2B
# Q2BOTHER
# Q3
# Q4A
# Q4B
# Q5
# Q6
# Q7
# Q8A
# Q8B
# Q8C
# Q8D
# Q8E
# Q8F
# Q9
# Q10A
# Q10B
# Q11A
# Q11B
# Q12A
# Q12B
# Q12C
# Q12D
# Q12E
# Q13
# Q14
# Q15
# Q16
# Q17
# Q18A
# Q18B
# Q18C
# Q18D
# Q19A
# Q19B
# Q19C
# Q19D
# Q19E
# Q20A
# Q20B
# Q21A
# Q21B
# Q22
# Q23
# Q24A
# Q24B
# Q25A
# Q25B
# Q25C
# Q25D
# Q25E
# Q25F
# Q26A
# Q26B
# Q26C
# Q26D
# Q26E
# Q27A
# Q27B
# Q27C
# Q28
# Q29
# Q30
# Q31
# Q32
# Q33
# Q34
# Q35
# Q36
# Q37
# Q38A
# Q38B
# Q38C
# Q38D
# Q38E
# Q38F
# Q38G
# Q39A
# Q39B
# Q39C
# Q40
# Q41
# Q42A
# Q42B
# Q42C
# Q42D
# Q42E
# Q42F
# Q43A
# Q43B
# Q43C
# Q43D
# Q43E
# Q43F
# Q43G
# Q43H
# Q43I
# Q43J
# Q43K
# Q44A
# Q44B
# Q44C
# Q44D
# Q44E
# Q44F
# Q44G
# Q44H
# Q44I
# Q44J
# Q45
# Q46
# Q47
# Q48A
# Q48B
# Q48C
# Q48D
# Q48E
# Q48F
# Q49A
# Q49B
# Q49C
# Q49D
# Q49E
# Q49F
# Q49G
# Q49H
# Q49I
# Q49J
# Q49K
# Q49L
# Q49M
# Q49N
# Q49O
# Q49P
# Q49Q
# Q49R
# Q49S
# Q49T
# Q50
# Q51
# Q52
# Q53A
# Q53B
# Q53C
# Q54A
# Q54B
# Q55PT1
# Q55PT1OTHER
# Q55PT2
# Q55PT2OTHER
# Q55PT3
# Q55PT3OTHER
# Q56A
# Q56B
# Q56C
# Q56D
# Q56E
# Q56F
# Q56G
# Q56H
# Q56I
# Q56J
# Q56K
# Q56L
# Q56M
# Q56N
# Q56O
# Q56P
# Q56Q
# Q56R
# Q56S
# Q57A
# Q57B
# Q57C
# Q57D
# Q57E
# Q57F
# Q57G
# Q58A
# Q58B
# Q58C
# Q58D
# Q58E
# Q59A
# Q59B
# Q59C
# Q60A
# Q60B
# Q60C
# Q60D
# Q61A
# Q61B
# Q61C
# Q62
# Q63
# Q64
# Q65
# Q66
# Q67
# Q68A
# Q68B
# Q69
# Q70
# Q70OTHER
# Q71
# Q72A
# Q72B
# Q73A
# Q73B
# Q74
# Q75
# Q76
# Q77A
# Q77B
# Q77C
# Q77D
# Q78A
# Q78B
# Q84
# Q84OTHER
# Q85A
# Q85B
# Q86A
# Q86B
# Q86C
# Q86D
# Q87A
# Q87B
# Q87C
# Q87D
# Q88A
# Q88B
# Q88BOTHER
# Q89A
# Q89B
# Q89C
# Q89D
# Q89E
# Q89F
# Q90
# Q91A
# Q91B
# Q92A
# Q92B
# Q93
# Q94
# Q95A
# Q95B
# Q95C
# Q96A
# Q96B
# Q97
# Q98
# Q98OTHER
# Q99
# Q99OTHER
# Q100
# ENDTIME
# LENGTH
# Q101
# Q102
# Q102OTHER
# Q103
# Q103OTHER
# Q104
# Q105
# Q106
# Q107A
# Q107B
# Q107C
# Q107D
# Q107E
# Q108
# Q108_2
# Q110A
# Q110B
# Q110C
# Q110D
# Q110E
# Q110F
# Q112
# Q113
# Q114
# Q115
# Q116
# Q116OTHER
# Q117
# Q117OTHER
# Q118
# Q119_1
# Q119_2
# Q119_3
# Q119_4
# Q119_5
# Q119_6
# Q119_7
# Q119_8
# Q119_9
# Q119_10
# Q119_11
# Q119OTHER
# withinwt
# Combinwt
# URBRUR_COND
# AGE_COND
# EDUC_COND
# RELIG_COND
# LivedPoverty
# LivedPoverty_CAT
# DemandDemo
# SupplyDemo
# R1.only
# R2.only
# R3.only
# R4.only
# R5.only
# R6.only

# %% [markdown]
# ## Country

# %%
country = df['COUNTRY']
country.dtype
# Out:
# CategoricalDtype(categories=['Benin', 'Botswana', 'Burkina Faso', 'Cabo Verde',
#                   'Cameroon', 'Côte d'Ivoire', 'Gabon', 'Gambia', 'Ghana',
#                   'Guinea', 'Kenya', 'Lesotho', 'Liberia', 'Madagascar',
#                   'Malawi', 'Mali', 'Mauritius', 'Morocco', 'Mozambique',
#                   'Namibia', 'Niger', 'Nigeria', 'Senegal', 'Sierra Leone',
#                   'South Africa', 'Sudan', 'São Tomé and Príncipe', 'Tanzania',
#                   'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe',
#                   'eSwatini'],
#                  ordered=False)

# %%
country.value_counts().sort_index()
# Out:
# Benin                    1200
# Botswana                 1198
# Burkina Faso             1200
# Cabo Verde               1200
# Cameroon                 1202
# Côte d'Ivoire            1200
# Gabon                    1199
# Gambia                   1200
# Ghana                    2400
# Guinea                   1194
# Kenya                    1599
# Lesotho                  1200
# Liberia                  1200
# Madagascar               1200
# Malawi                   1200
# Mali                     1200
# Mauritius                1200
# Morocco                  1200
# Mozambique               2392
# Namibia                  1200
# Niger                    1200
# Nigeria                  1600
# Senegal                  1200
# Sierra Leone             1200
# South Africa             1840
# Sudan                    1200
# São Tomé and Príncipe    1200
# Tanzania                 2400
# Togo                     1200
# Tunisia                  1199
# Uganda                   1200
# Zambia                   1200
# Zimbabwe                 1200
# eSwatini                 1200
# Name: COUNTRY, dtype: int64

# %%
df['COUNTRY.BY.REGION'].value_counts()
# Out:
# West Africa        18394
# Southern Africa    15030
# East Africa         5199
# Central Africa      3601
# North Africa        3599
# Name: COUNTRY.BY.REGION, dtype: int64

# %%
is_west = (df['COUNTRY.BY.REGION'] == 'West Africa')

# %%
df[is_west]['COUNTRY'].value_counts()
# Out:
# Ghana                    2400
# Nigeria                  1600
# Benin                    1200
# Gambia                   1200
# Mali                     1200
# Niger                    1200
# Senegal                  1200
# Sierra Leone             1200
# Côte d'Ivoire            1200
# Togo                     1200
# Cabo Verde               1200
# Burkina Faso             1200
# Liberia                  1200
# Guinea                   1194
# Gabon                       0
# Madagascar                  0
# Cameroon                    0
# Kenya                       0
# Lesotho                     0
# Botswana                    0
# eSwatini                    0
# Malawi                      0
# Zimbabwe                    0
# Morocco                     0
# Mozambique                  0
# Namibia                     0
# South Africa                0
# Sudan                       0
# São Tomé and Príncipe       0
# Tanzania                    0
# Tunisia                     0
# Uganda                      0
# Zambia                      0
# Mauritius                   0
# Name: COUNTRY, dtype: int64

# %% [markdown]
# ## Number of adult citizens
#
# As an example of a numerical variable, let's look at:
#
# >Question Number: ADULT_CT
# >
# >Question: Total number of adult citizens in household
# >
# >Variable Label: Number of adults in household
# >
# >Values: 1-99, 98, 999, -1
# >
# >Value Labels: 98=Refused to answer, 999= Don’t know, -1=Missing
# >
# >Source: Afrobarometer Round 4
# >
# >Note: Interviewer was given the following instructions: “Please record the total number of adult women/men (select correct gender, from above table) who are citizens of [ENTER COUNTRY] in the household, i.e., how many names did you write in either the left or the right column above. Enter a two-digit number.”

# %%
adult_ct = df['ADULT_CT']
adult_ct.dtype
# Out:
# dtype('float64')

# %%
adult_ct.value_counts().sort_index()
# Out:
# -1.0         8
#  1.0      6138
#  2.0     12567
#  3.0      8231
#  4.0      5776
#  5.0      4786
#  6.0      2995
#  7.0      1773
#  8.0      1270
#  9.0       623
#  10.0      634
#  11.0      189
#  12.0      215
#  13.0      110
#  14.0       95
#  15.0      130
#  16.0       40
#  17.0       31
#  18.0       52
#  19.0       19
#  20.0      140
#  23.0        1
# Name: ADULT_CT, dtype: int64

# %%
import numpy as np

adult_ct.replace(-1, np.nan, inplace=True)

# %%
adult_ct.describe()
# Out:
# count    45815.000000
# mean         3.713696
# std          2.643926
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          5.000000
# max         23.000000
# Name: ADULT_CT, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(adult_ct.dropna());

# %% [markdown]
# ## Age
#
# >Question Number: Q1
# >
# >Question: How old are you?
# >
# >Variable Label: Q1. Age
# >
# >Values: 18-105, 998-999, -1
# >
# >Value Labels: 98=Refused to answer, 999=Don’t know, -1=Missing

# %%
df['Q1'].dtype
# Out:
# CategoricalDtype(categories=[        18.0,         19.0,         20.0,         21.0,
#                           22.0,         23.0,         24.0,         25.0,
#                           26.0,         27.0,         28.0,         29.0,
#                           30.0,         31.0,         32.0,         33.0,
#                           34.0,         35.0,         36.0,         37.0,
#                           38.0,         39.0,         40.0,         41.0,
#                           42.0,         43.0,         44.0,         45.0,
#                           46.0,         47.0,         48.0,         49.0,
#                           50.0,         51.0,         52.0,         53.0,
#                           54.0,         55.0,         56.0,         57.0,
#                           58.0,         59.0,         60.0,         61.0,
#                           62.0,         63.0,         64.0,         65.0,
#                           66.0,         67.0,         68.0,         69.0,
#                           70.0,         71.0,         72.0,         73.0,
#                           74.0,         75.0,         76.0,         77.0,
#                           78.0,         79.0,         80.0,         81.0,
#                           82.0,         83.0,         84.0,         85.0,
#                           86.0,         87.0,         88.0,         89.0,
#                           90.0,         91.0,         92.0,         93.0,
#                           94.0,         95.0,         96.0,         97.0,
#                           98.0,         99.0,        103.0,        106.0,
#                   'Don't know',    'Refused'],
#                  ordered=False)

# %%
age = pd.to_numeric(df['Q1'], errors='coerce')
age.dtype
# Out:
# dtype('float64')

# %%
age.describe()
# Out:
# count    45777.000000
# mean        37.143609
# std         14.935553
# min         18.000000
# 25%         25.000000
# 50%         34.000000
# 75%         46.000000
# max        106.000000
# Name: Q1, dtype: float64

# %%
age.value_counts().sort_index()
# Out:
# 18.0     1540
# 19.0     1492
# 20.0     1672
# 21.0     1242
# 22.0     1557
#          ...
# 97.0        1
# 98.0        4
# 99.0        5
# 103.0       1
# 106.0       2
# Name: Q1, Length: 84, dtype: int64

# %%
plt.hist(age.dropna());

# %% [markdown]
# ## Electricity
#
# >Question Number: EA_SVC_A
# >
# >Question: Are the following services present in the primary sampling unit/enumeration area: Electricity grid
# that most houses could access?
# >
# >Variable Label: EA-SVC-A. Electricity grid in the PSU/EA
# >
# >Values: 0, 1, 9, -1
# >
# >Value Labels: 0=No, 1=Yes, 9=Can’t determine, -1=Missing
# >
# >Source: SAB
# >
# >Note: Question was filled in conjunction with field supervisor
#
# Related variables indicate the availability of piped water, sewage, cell phone service, post office, schools, police stations, health clinics, market stalls, banks, paid transport, etc.

# %%
df['EA_SVC_A'].dtype
# Out:
# CategoricalDtype(categories=['Can't determine', 'Missing', 'No', 'Yes'], ordered=False)

# %%
df['EA_SVC_A'].value_counts().sort_index()
# Out:
# Can't determine      140
# Missing                8
# No                 15772
# Yes                29903
# Name: EA_SVC_A, dtype: int64

# %%
elec_yes = (df['EA_SVC_A'] == 'Yes')
elec_yes.sum()
# Out:
# 29903

# %%
elec_yes.mean()    # warning, this is misleading if there are invalid responses
# Out:
# 0.6525762171835104

# %%
elec_no = (df['EA_SVC_A'] == 'No')
elec_no.sum()
# Out:
# 15772

# %%
elec_yes.sum() / (elec_yes.sum() + elec_no.sum())
# Out:
# 0.6546907498631637

# %%
def fraction_yes(df, column):
    """Fraction of yes responses out of (yes+no)
    
    Ignores other responses.
    
    df: DataFrame
    column: string column name
    
    returns: fraction between 0 and 1
    """
    yes = (df[column] == 'Yes').sum()
    no = (df[column] == 'No').sum()
    return yes / (yes + no)

# %%
fraction_yes(df, 'EA_SVC_A')
# Out:
# 0.6546907498631637

# %%
is_ghana = (df['COUNTRY'] == 'Ghana')
is_ghana.sum()
# Out:
# 2400

# %%
fraction_yes(df[is_ghana], 'EA_SVC_A')
# Out:
# 0.9066666666666666

# %% [markdown]
# ## Resampling
#
# >Question Number: withinwt
# >
# >Variable Label: Within country weighting factor
# >
# >Note: The weighting variable adjusts the distribution of the sample based on individual selection probabilities (i.e. based on region, gender, urban-rural distribution, and size of household and enumeration area).

# %%
df['withinwt'].describe()
# Out:
# count    45823.000000
# mean         0.999740
# std          0.433214
# min          0.028752
# 25%          0.742495
# 50%          0.964786
# 75%          1.183728
# max          6.660400
# Name: withinwt, dtype: float64

# %%
def resample_rows_weighted(df, column):
    """Resamples a DataFrame using probabilities proportional to given column.

    df: DataFrame
    column: string column name to use as weights

    returns: DataFrame
    """
    weights = df[column]
    sample = df.sample(n=len(df), replace=True, weights=weights)
    return sample

# %%
def resample_by_country(df, column):
    """Resample rows within each year.

    df: DataFrame
    column: string name of weight variable

    returns DataFrame
    """
    grouped = df.groupby('COUNTRY')
    samples = [resample_rows_weighted(group, column)
               for _, group in grouped]
    sample = pd.concat(samples, ignore_index=True)
    return sample

# %%
# %time sample = resample_by_country(df, 'withinwt')
# Out:
# CPU times: user 11 s, sys: 778 µs, total: 11 s
# Wall time: 11 s

# %%
fraction_yes(sample, 'EA_SVC_A')
# Out:
# 0.6583747563886395

# %%
is_ghana = (sample['COUNTRY'] == 'Ghana')
is_ghana.sum()
# Out:
# 2400

# %%
fraction_yes(sample[is_ghana], 'EA_SVC_A')
# Out:
# 0.925
